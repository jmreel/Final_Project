# %%
import pandas as pd 

df= pd.read_excel(r'/Users/johnmorrissey/Downloads/2020-Report-Card-Public-Data.xlsx')

df.head(30)
# Out:
#               RCDTS      Type                             School Name  \
# 0   010010010260000  District                                     NaN
# 1   010010010260001    School                     Seymour High School
# 2   010010010262002    School               Seymour Elementary School
# 3   010010020260000  District                                     NaN
# 4   010010020260001    School                     Liberty High School
# 5   010010020262002    School               Liberty Elementary School
# 6   010010030260000  District                                     NaN
# 7   010010030260001    School                     Central High School
# 8   010010030261001    School              Central Junior High School
# 9   010010030262003    School         Central Elementary Grade School
# 10  010010030262008    School               Central 3-4 Middle School
# 11  010010040260000  District                                     NaN
# ...

# %%
df.isna().sum()
# Out:
# RCDTS                                                                                                         0
# Type                                                                                                          0
# School Name                                                                                                 868
# District                                                                                                      1
# City                                                                                                          1
#                                                                                                            ...
# % Students Identified as Gifted, Taught by Gifted-endorsed Teachers  - American Indian or Alaska Native    4726
# % Students Identified as Gifted, Taught by Gifted-endorsed Teachers  - Two or More Race                    4706
# ...

# %%
df_filtered = df.loc[df['Type'] == "District"]

# %%
df_filtered
# Out:
#                 RCDTS      Type School Name  \
# 0     010010010260000  District         NaN
# 3     010010020260000  District         NaN
# 6     010010030260000  District         NaN
# 11    010010040260000  District         NaN
# 15    010011720220000  District         NaN
# ...               ...       ...         ...
# 4692  56099365U260000  District         NaN
# 4713  601054280300000  District         NaN
# 4720  651089010800000  District         NaN
# 4723  651089020800000  District         NaN
# 4725  651089030800000  District         NaN
#
#                                     District        City               County  \
# 0                              Payson CUSD 1      Payson                Adams
# 3                             Liberty CUSD 2     Liberty                Adams
# 6                             Central CUSD 3  Camp Point                Adams
# 11                                    CUSD 4      Mendon                Adams
# ...

# %%
df_filtered.isna().sum()
# Out:
# RCDTS                                                                                                        0
# Type                                                                                                         0
# School Name                                                                                                867
# District                                                                                                     0
# City                                                                                                         0
#                                                                                                           ...
# % Students Identified as Gifted, Taught by Gifted-endorsed Teachers  - American Indian or Alaska Native    867
# % Students Identified as Gifted, Taught by Gifted-endorsed Teachers  - Two or More Race                    856
# ...

# %%
df_filtered = df_filtered

# %%
df_filtered = df_filtered.dropna(thresh=750, axis=1)

# %%
list(df_filtered.columns)
# Out:
# ['RCDTS',
#  'Type',
#  'District',
#  'City',
#  'County',
#  'District Type',
#  'District Size',
#  'Grades Served',
#  '# Student Enrollment',
#  '% Student Enrollment - White',
#  '% Student Enrollment - Black or African American',
#  '% Student Enrollment - Hispanic or Latino',
#  '% Student Enrollment - Two or More Races',
#  '% Student Enrollment - Children with Disabilities',
#  '% Student Enrollment - IEP',
#  '% Student Enrollment - Low Income',
#  '% Student Enrollment - Homeless',
#  'Total Number of School Days',
#  'Student Attendance Rate',
#  'Student Mobility Rate',
#  'Student Mobility Rate - Male',
#  'Student Mobility Rate - Female',
#  'Student Mobility Rate - White',
#  'Student Mobility Rate - Children with Disabilities',
#  'Student Mobility Rate - IEP',
#  'Student Mobility Rate - Low Income',
#  'Chronically Truant Students',
#  'Student Chronic Truancy Rate',
#  'Avg Class Size - 8',
#  'Avg Class Size – All Grades',
# ...

# %%
df_filtered.dropna(axis=0)
# Out:
#                 RCDTS      Type               District        City County  \
# 6     010010030260000  District         Central CUSD 3  Camp Point  Adams
# 15    010011720220000  District          Quincy SD 172      Quincy  Adams
# 28    010090150260000  District     Beardstown CUSD 15  Beardstown   Cass
# 32    010090640260000  District       Virginia CUSD 64    Virginia   Cass
# 35    010092620260000  District   A-C Central CUSD 262     Ashland   Cass
# ...               ...       ...                    ...         ...    ...
# 4666  560992030040000  District        Elwood CCSD 203      Elwood   Will
# 4673  56099207U260000  District      Peotone CUSD 207U     Peotone   Will
# 4679  56099209U260000  District   Wilmington CUSD 209U  Wilmington   Will
# 4688  56099255U260000  District  Reed Custer CUSD 255U   Braidwood   Will
# 4692  56099365U260000  District  Valley View CUSD 365U  Romeoville   Will
#
#      District Type District Size                    Grades Served  \
# ...

# %%
list(df_filtered.columns)
# Out:
# ['RCDTS',
#  'Type',
#  'District',
#  'City',
#  'County',
#  'District Type',
#  'District Size',
#  'Grades Served',
#  '# Student Enrollment',
#  '% Student Enrollment - White',
#  '% Student Enrollment - Black or African American',
#  '% Student Enrollment - Hispanic or Latino',
#  '% Student Enrollment - Two or More Races',
#  '% Student Enrollment - Children with Disabilities',
#  '% Student Enrollment - IEP',
#  '% Student Enrollment - Low Income',
#  '% Student Enrollment - Homeless',
#  'Total Number of School Days',
#  'Student Attendance Rate',
#  'Student Mobility Rate',
#  'Student Mobility Rate - Male',
#  'Student Mobility Rate - Female',
#  'Student Mobility Rate - White',
#  'Student Mobility Rate - Children with Disabilities',
#  'Student Mobility Rate - IEP',
#  'Student Mobility Rate - Low Income',
#  'Chronically Truant Students',
#  'Student Chronic Truancy Rate',
#  'Avg Class Size - 8',
#  'Avg Class Size – All Grades',
# ...
